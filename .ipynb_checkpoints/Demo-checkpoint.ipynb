# %%
import splusdata

# %%
conn = splusdata.connect('matias', 'asdf') ## from splus.cloud

# %%
conn.get_tap_tables()
# Out:
# Tables and columns info available at https://splus.cloud/query/

# %%
conn.twelve_band_img(43.3559, -0.2322, radius=200, noise=0.15, saturation=0.15) ## Get 12 band image RA, DEC, Radius
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x7FC04A0E4A90>

# %%
conn.get_img(43.3559, -0.2322, 200, R="I", G="R", B="G", stretch=0.5, Q=5) ## Fast image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x7FC04A0E4DC0>

# %%
conn.get_img(43.3559, -0.2322, 200, R="I", G="R", B="Z", stretch=0.5, Q=5) ## Fast image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200 at 0x7FC04A1AC070>

# %%
conn.get_cut(0.4, 0.7, 1500, 'R') ## image FITS cuts - RA, DEC, Radius, band
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x11c5e3220>, <astropy.io.fits.hdu.compressed.CompImageHDU object at 0x11c6bd910>]

# %%
conn.get_field('STRIPE82-0002', 'R') ## Field image FITS - Field, band
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x11c447490>, <astropy.io.fits.hdu.compressed.CompImageHDU object at 0x11c447c70>]

# %%
conn.query('select id, ra, dec from dr2.detection_image where ra + dec > 200') ## async query on splus.cloud
# Out:
# Executing
# Executing
# finished
# <Table length=20000>
#            ID                    RA                 DEC
#         bytes24               float64             float64
# ------------------------ ------------------ -------------------
# iDR3.SPLUS-s23s33.010418  333.7759977857468 -30.030742709540895
# iDR3.SPLUS-s23s33.010419 333.59822625942826  -30.03080183761246
# iDR3.SPLUS-s23s33.010420 332.89100208605424 -30.028743448904237
# iDR3.SPLUS-s23s33.010421  333.6314965762763 -30.030732361108342
# iDR3.SPLUS-s23s33.010422  333.6211313472873 -30.030804730977245
# iDR3.SPLUS-s23s33.010423  334.1797717262945 -30.029547747420853
# iDR3.SPLUS-s23s33.010424  333.5640182619402 -30.030655294250693
# iDR3.SPLUS-s23s33.010425 334.42889146812354  -30.02805501815738
# iDR3.SPLUS-s23s33.010426 334.41127134964114 -30.028263281566204
# iDR3.SPLUS-s23s33.010427 333.48268803771543  -30.03054441077405
#                      ...                ...                 ...
# ...

# %%
conn.get_last_result() ## Returns result of the last operation made
